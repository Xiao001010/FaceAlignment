# %%
import torchlm
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# Load the data that only has a subset of annotations using np.load
data = np.load('data/training_images_subset.npz', allow_pickle=True)

# Extract the images
images_subset = data['images']
# and the data points
pts_subset = data['points']

idx = 20

img_raw = images_subset[idx]
pts_raw = pts_subset[idx]

# # Plot the image
# plt.imshow(img_raw)
# # Plot the points
# plt.scatter(pts_raw[:, 0], pts_raw[:, 1], c='b', s=10)
# plt.show()

# %%
trans = torchlm.LandmarksResize((224, 224))

img_raw, pts_raw = trans(img_raw, pts_raw)
# Plot the image
plt.imshow(img_raw)
# Plot the points
plt.scatter(pts_raw[:, 0], pts_raw[:, 1], c='b', s=10)
plt.show()

# %%
import math
import cv2

left_eye = pts_raw[0]
right_eye = pts_raw[1]
dx = (right_eye[0] - left_eye[0])
dy = (right_eye[1] - left_eye[1])
angle = math.atan2(dy, dx) * 180 / math.pi  # calc angle

print(angle)

(h, w) = img_raw.shape[:2]
(cX, cY) = (w // 2, h // 2)

# grab the rotation matrix (applying the negative of the
# angle to rotate clockwise), then grab the sine and cosine
# (i.e., the rotation components of the matrix)
M = cv2.getRotationMatrix2D((cX, cY), angle, 1.0)
cos = np.abs(M[0, 0])
sin = np.abs(M[0, 1])

# perform the actual rotation and return the image
img_ro = cv2.warpAffine(img_raw.copy(), M, (w, h))

img_ro = img_ro.astype(np.uint8)

pts_ro = np.hstack((pts_raw, np.ones((pts_raw.shape[0], 1), dtype=type(pts_raw[0][0]))))
print(pts_ro.shape)

pts_ro = np.dot(M, pts_ro.T).T
print(pts_ro.shape)

# Plot the image
plt.imshow(img_ro)
# Plot the points
plt.scatter(pts_ro[:, 0], pts_ro[:, 1], c='b', s=10)
plt.show()

print(img_ro.shape)
# Out:
# 14.763043543572506
# (5, 3)
# (5, 2)
# (224, 224, 3)

# %%
(h, w) = img_ro.shape[:2]
(cX, cY) = (w // 2, h // 2)

# grab the rotation matrix (applying the negative of the
# angle to rotate clockwise), then grab the sine and cosine
# (i.e., the rotation components of the matrix)
M = cv2.getRotationMatrix2D((cX, cY), -angle, 1.0)
cos = np.abs(M[0, 0])
sin = np.abs(M[0, 1])

# # compute the new bounding dimensions of the image
# nW = int((h * sin) + (w * cos))
# nH = int((h * cos) + (w * sin))

# # adjust the rotation matrix to take into account translation
# M[0, 2] += (nW / 2) - cX
# M[1, 2] += (nH / 2) - cY

# perform the actual rotation and return the image
img_ = cv2.warpAffine(img_ro, M, (w, h))

#    image = cv2.resize(image, (w,h))
img_ro = img_.astype(np.uint8)

pts_restore = np.hstack((pts_ro, np.ones((pts_ro.shape[0], 1), dtype=type(pts_ro[0][0]))))
print(pts_restore.shape)

pts_restore = np.dot(M, pts_restore.T).T
print(pts_restore.shape)

# Plot the image
plt.imshow(img_ro)
# Plot the points
plt.scatter(pts_restore[:, 0], pts_restore[:, 1], c='b', s=10)
plt.show()
print(img_.shape)
# Out:
# (5, 3)
# (5, 2)
# (224, 224, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import torchlm

# # from affineTransform import *

# # Load the data that only has a subset of annotations using np.load
# data = np.load('data/training_images_subset.npz', allow_pickle=True)

# # Extract the images
# images_subset = data['images']
# # and the data points
# pts_subset = data['points']

# # idx = 20

# trans = torchlm.LandmarksResize((224, 224))

# for i in range(3):
#     img_raw = images_subset[i]
#     pts_raw = pts_subset[i]
#     img_raw, pts_raw = trans(img_raw, pts_raw)
#     # Plot the image
#     plt.imshow(img_raw)
#     # Plot the points
#     plt.scatter(pts_raw[:, 0], pts_raw[:, 1], c='b', s=10)
#     plt.show()

# %%
def Align(image, landmarks, eyes_index=[0, 1]):
    if eyes_index is None or len(eyes_index) != 2:
        raise ValueError("2 indexes in landmarks, "
                            "which indicates left and right eye center.")

    left_eye = landmarks[eyes_index[0]]
    right_eye = landmarks[eyes_index[1]]
    dx = (right_eye[0] - left_eye[0])
    dy = (right_eye[1] - left_eye[1])
    angle = math.atan2(dy, dx) * 180 / math.pi  # calc angle

    w, h = image.shape[1], image.shape[0]
    cx, cy = w // 2, h // 2

    # grab the rotation matrix (applying the negative of the
    # angle to rotate clockwise), then grab the sine and cosine
    # (i.e., the rotation components of the matrix)
    M = cv2.getRotationMatrix2D((cx, cy), angle, 1.0)

    # perform the actual rotation and return the image
    new_img = cv2.warpAffine(image.copy(), M, (w, h))

    new_landmarks = np.hstack((landmarks, np.ones((landmarks.shape[0], 1), dtype=type(landmarks[0][0]))))
    new_landmarks = np.dot(M, new_landmarks.T).T

    return new_img.astype(np.uint8), [new_landmarks.astype(np.float32), angle.astype(np.float32)]


def Recover(image, landmarks, angle):
    w, h = image.shape[1], image.shape[0]
    cx, cy = w // 2, h // 2

    # grab the rotation matrix (applying the negative of the
    # angle to rotate clockwise), then grab the sine and cosine
    # (i.e., the rotation components of the matrix)
    M = cv2.getRotationMatrix2D((cx, cy), -angle, 1.0)

    # perform the actual rotation and return the image
    new_img = cv2.warpAffine(image.copy(), M, (w, h))

    new_landmarks = np.hstack((landmarks, np.ones((landmarks.shape[0], 1), dtype=type(landmarks[0][0]))))
    new_landmarks = np.dot(M, new_landmarks.T).T

    return new_img.astype(np.uint8), new_landmarks.astype(np.float32)

# %%
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torchlm

from datasets import FaceDataset

dataset = FaceDataset("data/training_images_full.npz", partial=True, augment=False)
loader = DataLoader(dataset, batch_size=5, shuffle=False)
for idx, (img_batch, pts_batch) in enumerate(loader):
    img_batch, pts_batch  = torchlm.LandmarksUnNormalize()(img_batch, pts_batch)
    print(img_batch.shape, pts_batch.shape)
    pts = pts_batch[1].reshape(-1, 2)
    img = img_batch[1].numpy()
    img = img.astype(np.uint8)
    print(pts.shape, img.shape)
    img = np.transpose(img, (1, 2, 0))
    print(img.shape)
    img, pts = torchlm.LandmarksResize((256, 256))(img, pts)
    print(pts)
    plt.imshow(img)
    plt.plot(pts[:, 0], pts[:, 1], 'bx')
    plt.show()
    break
# Out:
# torch.Size([5, 3, 224, 224]) torch.Size([5, 10])
# torch.Size([5, 2]) (3, 224, 224)
# (224, 224, 3)
# tensor([[ 82.0042, 118.7918],
#         [180.8841,  88.6746],
#         [130.9239, 154.5285],
#         [124.2607, 184.2824],
#         [180.5316, 170.5078]])

# %%
trans = torchlm.LandmarksCompose([torchlm.bind(Align, bind_type=torchlm.BindEnum.Callable_Array, prob=1.0)])

img_batch_ro, pts_batch_ro  = trans(img_batch, pts_batch)
print(img_batch_ro.shape, pts_batch_ro.shape)
pts = pts_batch_ro[1].reshape(-1, 2)
img = img_batch_ro[1].numpy().astype(np.uint8)

print(pts.shape, img.shape)
img = np.transpose(img, (1, 2, 0))
print(pts)
plt.imshow(img)
plt.plot(pts[:, 0], pts[:, 1], 'bx')
plt.show()
# Out:
# torch.Size([5, 3, 224, 224]) torch.Size([5, 10])
# torch.Size([5, 2]) (3, 224, 224)
# tensor([[ 71.7536, 103.9428],
#         [158.2736,  77.5903],
#         [114.5584, 135.2124],
#         [108.7282, 161.2471],
#         [157.9652, 149.1943]])

# %%
import math
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torchlm

# Load the data that only has a subset of annotations using np.load
data = np.load('data/training_images_full.npz', allow_pickle=True)

# Extract the images
images = data['images']
# and the data points
pts = data['points']

idx = 32

img_raw = images[idx]
pts_raw = pts[idx]
print(img_raw.shape, pts_raw.shape)

# Plot the image
plt.imshow(img_raw)
# Plot the points
plt.scatter(pts_raw[:, 0], pts_raw[:, 1], c='b', s=10)
plt.show()
# Out:
# (256, 256, 3) (44, 2)

# %%
def Align(image, landmarks, eyes):
    left_eye = eyes[0]
    right_eye = eyes[1]
    dx = (right_eye[0] - left_eye[0])
    dy = (right_eye[1] - left_eye[1])
    angle = math.atan2(dy, dx) * 180 / math.pi  # calc angle

    w, h = image.shape[1], image.shape[0]
    cx, cy = w // 2, h // 2

    # grab the rotation matrix (applying the negative of the
    # angle to rotate clockwise), then grab the sine and cosine
    # (i.e., the rotation components of the matrix)
    M = cv2.getRotationMatrix2D((cx, cy), angle, 1.0)

    # perform the actual rotation and return the image
    new_img = cv2.warpAffine(image.copy(), M, (w, h))

    new_landmarks = np.hstack((landmarks, np.ones((landmarks.shape[0], 1), dtype=type(landmarks[0][0]))))
    new_landmarks = np.dot(M, new_landmarks.T).T

    return new_img.astype(np.uint8), new_landmarks.astype(np.float32), angle

# %%
print(pts_raw[[20, 29]])
img_align, pts_align, angle = Align(img_raw, pts_raw, eyes=pts_raw[[20, 29]])
print(img_align.shape, pts_align.shape, angle)
plt.imshow(img_align)
plt.plot(pts_align[:, 0], pts_align[:, 1], 'bo')
plt.show()
# Out:
# [[ 71.25170954 122.81500622]
#  [176.47302814  84.86853287]]
# (256, 256, 3) (44, 2) -19.831070282956283

# %%
trans = torchlm.LandmarksCompose([
    torchlm.LandmarksResize((224, 224)), 
    torchlm.LandmarksToTensor(), 
    torchlm.LandmarksNormalize()])

img_tensor, pts_tensor = trans(img_align, pts_align)
print(img_tensor.shape, pts_tensor.shape)
# Out:
# torch.Size([3, 224, 224]) torch.Size([44, 2])

# %%
def Recover(image, landmarks, angle):
    w, h = image.shape[1], image.shape[0]
    cx, cy = w // 2, h // 2

    # grab the rotation matrix (applying the negative of the
    # angle to rotate clockwise), then grab the sine and cosine
    # (i.e., the rotation components of the matrix)
    M = cv2.getRotationMatrix2D((cx, cy), -angle, 1.0)

    # perform the actual rotation and return the image
    new_img = cv2.warpAffine(image.copy(), M, (w, h))

    new_landmarks = np.hstack((landmarks, np.ones((landmarks.shape[0], 1), dtype=type(landmarks[0][0]))))
    new_landmarks = np.dot(M, new_landmarks.T).T

    return new_img.astype(np.uint8), new_landmarks.astype(np.float32)

# %%
from utils import Recover

print(img_tensor.shape, pts_tensor.shape, angle) 
img_recover, pts_recover = Recover(img_tensor, pts_tensor, angle, size=(256, 256))
print(img_recover.shape, pts_recover.shape)

plt.imshow(img_recover)
plt.plot(pts_recover[:, 0], pts_recover[:, 1], 'bo')
plt.show()
# Out:
# torch.Size([3, 224, 224]) torch.Size([44, 2]) -19.831070282956283
# (256, 256, 3) (44, 2)

# %%
# trans_recover = torchlm.LandmarksCompose([
#     torchlm.LandmarksUnNormalize(),
#     torchlm.LandmarksResize((256, 256))])

img_recover, pts_recover = torchlm.LandmarksUnNormalize()(img_tensor, pts_tensor)
print(img_recover.shape, pts_recover.shape)
print(type(img_recover), type(pts_recover), isinstance(img_recover, torch.Tensor), isinstance(pts_recover, torch.Tensor))

img_recover, pts_recover = img_recover.numpy().astype(np.uint8), pts_recover.numpy()
img_recover = np.transpose(img_recover, (1, 2, 0))
print(img_recover.shape, pts_recover.shape)

img_recover, pts_recover = Recover(img_recover, pts_recover, angle)
print(img_recover.shape, pts_recover.shape)

plt.imshow(img_recover)
plt.plot(pts_recover[:, 0], pts_recover[:, 1], 'bo')
plt.show()
# Out:
# torch.Size([3, 224, 224]) torch.Size([44, 2])
# <class 'torch.Tensor'> <class 'torch.Tensor'> True True
# (224, 224, 3) (44, 2)
# (224, 224, 3) (44, 2)

# %%
img_resize, pts_resize = torchlm.LandmarksResize((256, 256))(img_recover, pts_recover)
print(img_resize.shape, pts_resize.shape)
print(pts_resize[[20, 29]])

plt.imshow(img_resize)
plt.plot(pts_resize[:, 0], pts_resize[:, 1], 'bo')
plt.show()
# Out:
# (256, 256, 3) (44, 2)
# [[ 71.25171 122.81501]
#  [176.47302  84.86854]]

# %%
pts_raw[[20, 32, 29]], pts_resize[[20, 32, 29]]
# Out:
# (array([[ 71.25170954, 122.81500622],
#         [122.30955633, 193.36379303],
#         [176.47302814,  84.86853287]]),
#  array([[ 71.25171, 122.81501],
#         [122.30956, 193.3638 ],
#         [176.47302,  84.86854]], dtype=float32))

# %%
print(type(img_recover), type(pts_recover), type(angle), type(img_resize), type(pts_resize))
print(isinstance(img_recover, np.ndarray), isinstance(pts_recover, np.ndarray), isinstance(angle, float))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'float'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# True True True
